# %% [markdown]
# #### Luqman

# %% [markdown]
# #### To what extent do parental education/occupation (Mother’s qualification, Father’s qualification, Mother’s occupation, Father’s occupation) and home-country economic indicators (unemployment, inflation, GDP) affect students’ academic performance and persistence?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
spQ2 = pd.read_csv("spQ2.csv")
spQ2.head()
# Out:
#    Mother's qualification  Father's qualification  Mother's occupation  \
# 0                      19                      12                    5
# 1                       1                       3                    3
# 2                      37                      37                    9
# 3                      38                      37                    5
# 4                      37                      38                    9
#
#    Father's occupation  Unemployment rate  Inflation rate   GDP  Target_status
# 0                    9               10.8             1.4  1.74              1
# 1                    3               13.9            -0.3  0.79              2
# 2                    9               10.8             1.4  1.74              1
# 3                    3                9.4            -0.8 -3.12              2
# 4                    9               13.9            -0.3  0.79              2

# %%
sns.heatmap(spQ2.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
sns.heatmap(spQ2.corr()[["Target_status"]], square=True, annot=True, fmt=".2f")

# %%
top10 = spQ2["Mother\'s occupation"].value_counts().nlargest(10).index

ax = sns.countplot(
    x="Mother\'s occupation",
    hue="Target_status",
    data=spQ2[spQ2["Mother\'s occupation"].isin(top10)],
    order=top10,                # keep top 10 order
    palette="Set1"              # more contrasting colors
)
# Rename legend title and labels
ax.legend(title="Target_status", labels=["Dropout", "Graduated", "Enrolled"])

plt.xticks(rotation=45)
plt.show()

# %%
top10 = spQ2["Father\'s occupation"].value_counts().nlargest(10).index

ax = sns.countplot(
    x="Father\'s occupation",
    hue="Target_status",
    data=spQ2[spQ2["Father\'s occupation"].isin(top10)],
    order=top10,                # keep top 10 order
    palette="Set1"              # more contrasting colors
)
# Rename legend title and labels
ax.legend(title="Target_status", labels=["Dropout", "Graduated", "Enrolled"])

plt.xticks(rotation=45)
plt.show()

# %%
top10 = spQ2["Mother\'s qualification"].value_counts().nlargest(10).index

ax = sns.countplot(
    x="Mother\'s qualification",
    hue="Target_status",
    data=spQ2[spQ2["Mother\'s qualification"].isin(top10)],
    order=top10,                # keep top 10 order
    palette="Set1"              # more contrasting colors
)
# Rename legend title and labels
ax.legend(title="Target_status", labels=["Dropout", "Graduated", "Enrolled"])

plt.xticks(rotation=45)
plt.show()

# %%
top10 = spQ2["Father\'s qualification"].value_counts().nlargest(10).index

ax = sns.countplot(
    x="Father\'s qualification",
    hue="Target_status",
    data=spQ2[spQ2["Father\'s qualification"].isin(top10)],
    order=top10,                # keep top 10 order
    palette="Set1"              # more contrasting colors
)
# Rename legend title and labels
ax.legend(title="Target_status", labels=["Dropout", "Graduated", "Enrolled"])
plt.xticks(rotation=45)
plt.show()

# %%
ax = sns.boxplot(
    x="Target_status",
    y="Inflation rate",
    data=spQ2,
    palette="Set1"
)
# Rename labels on x axis
ax.set_xticklabels(["Dropout", "Graduated", "Enrolled"])
plt.show()
# Out:
# C:\Users\luqma\AppData\Local\Temp\ipykernel_19492\1418593725.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# C:\Users\luqma\AppData\Local\Temp\ipykernel_19492\1418593725.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Dropout", "Graduated", "Enrolled"])

# %%
ax = sns.boxplot(
    x="Target_status",
    y="Unemployment rate",
    data=spQ2,
    palette="Set1"
)
ax.set_xticklabels(["Dropout", "Graduated", "Enrolled"])
plt.show()
# Out:
# C:\Users\luqma\AppData\Local\Temp\ipykernel_19492\3950429072.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# C:\Users\luqma\AppData\Local\Temp\ipykernel_19492\3950429072.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Dropout", "Graduated", "Enrolled"])

# %%
ax = sns.boxplot(
    x="Target_status",
    y="GDP",
    data=spQ2,
    palette="Set1"
)
ax.set_xticklabels(["Dropout", "Graduated", "Enrolled"])
#plt.savefig('GR.png', format='png', dpi=300)
plt.show()
# Out:
# C:\Users\luqma\AppData\Local\Temp\ipykernel_19492\2995880912.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# C:\Users\luqma\AppData\Local\Temp\ipykernel_19492\2995880912.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Dropout", "Graduated", "Enrolled"])

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
encoder = LabelEncoder()
spQ2['Target_status'] = encoder.fit_transform(spQ2['Target_status'])

X = spQ2.drop("Target_status", axis=1)     # drop labels from original data
y = spQ2["Target_status"].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# check shapes after splitting
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (3318, 7)
# (3318,)
# (1106, 7)
# (1106,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
rf_classifier = RandomForestClassifier(n_estimators=200, random_state=42)
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
y_pred = rf_classifier.predict(X_test)

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.34      0.35       340
#            1       0.55      0.64      0.59       565
#            2       0.29      0.20      0.24       201
#
#     accuracy                           0.47      1106
#    macro avg       0.40      0.39      0.39      1106
# weighted avg       0.45      0.47      0.45      1106
